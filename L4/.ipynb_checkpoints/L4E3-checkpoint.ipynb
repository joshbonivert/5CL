# %%
import numpy as np
import pandas as pd
import scipy.optimize as opt
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

def model(x, m, b):
    return m * x + b

def get_x_int(m, b):
    return -b / m

# %%
mV_b = np.array([0.0, -100, -200, -300, -400, -500, -600, -700, -800, -850, -900, -925, -950, -975, -1000, -1100, 100, 200, 300, 400, 500])
nA_b = np.array([4926, 4180, 3356, 2585, 1883, 1280, 789, 423, 178, 92, 47, 29, 14, 3, 0, 0, 6356, 7324, 8274, 9262, 10220])
mV_b = np.sort(mV_b)
nA_b = np.sort(nA_b)

mV_r = np.array([0.0, -100, -200, -225, -250, -275, -300, -400, -600, 100, 200, 300, 400, 500])
nA_r = np.array([318, 114, 21, 14, 7, 3, 0, 0, 0, 611, 902, 1188, 1473, 1739])
mV_r = np.sort(mV_r)
nA_r = np.sort(nA_r)

mV_g = np.array([0.0, -200, -400, -500, -600, -650, -700, -725, -750, 100, 200, 300, 400, 500])
nA_g = np.array([2230, 1067, 276, 90, 23, 5, 3, 0, 0, 2887, 3511, 4135, 4752, 5369])
mV_g = np.sort(mV_g)
nA_g = np.sort(nA_g)

# %%
# Does the fit
init_params=[0, 0]
lin_opt, lin_cov = opt.curve_fit(model, mV_b[10:], nA_b[10:], p0=init_params)

# Best fit values
m, b = lin_opt

plt.scatter(mV_b, nA_b)
plt.plot(mV_b[9:], model(mV_b[9:], m, b), color='orange')

get_x_int(m, b)
# Out:
# -588.2538586182858

# %%
# Does the fit
init_params=[0, 0]
lin_opt, lin_cov = opt.curve_fit(model, mV_r[7:], nA_r[7:], p0=init_params)

# Best fit values
m, b = lin_opt

plt.scatter(mV_r, nA_r)
plt.plot(mV_r[7:], model(mV_r[7:], m, b), color='orange')

get_x_int(m, b)
# Out:
# -126.97758302277434

# %%
# Does the fit
init_params=[0, 0]
lin_opt, lin_cov = opt.curve_fit(model, mV_g[6:], nA_g[6:], p0=init_params)

# Best fit values
m, b = lin_opt

plt.scatter(mV_g, nA_g)
plt.plot(mV_g[6:], model(mV_g[6:], m, b), color='orange')

get_x_int(m, b)
# Out:
# -408.99435575229495

# %%
stopping = np.array([975, 700, 275]) * 10**-3
eV = 1.602176634e-19 * stopping
wavelength = np.array([463, 513, 618]) * 10**-9
freq = 299792458 / wavelength

# %%
# Does the fit
init_params=[0, 0]
lin_opt, lin_cov = opt.curve_fit(model, freq, eV, p0=init_params)

# Best fit values
m, b = lin_opt

plt.scatter(freq, eV)
plt.plot(np.array([-100, 630]), model(np.array([-100, 630]), m, b), color='orange')

# %%
get_x_int(m, b) * 10**-14
# Out:
# 4.214379245907165

# %%
m
# Out:
# 6.901693336110656e-34

# %%
b
# Out:
# -2.908635315732053e-19
